# %%
import requests
from datetime import datetime
import pandas as pd

# %%
def extract_crypto_data():
    url = f"https://api4.binance.com/api/v3/ticker/24hr"
    response = requests.get(url)
    data = response.json()
    df= pd.DataFrame(data)
    return df

extract_crypto_data()
# Out:
#         symbol   priceChange priceChangePercent weightedAvgPrice  \
# 0       ETHBTC   -0.00049000             -2.565       0.01883238
# 1       LTCBTC   -0.00001100             -1.228       0.00089215
# 2       BNBBTC   -0.00000400             -0.058       0.00692030
# 3       NEOBTC   -0.00000010             -0.155       0.00006457
# 4      QTUMETH    0.00004300              3.551       0.00124732
# ...        ...           ...                ...              ...
# 3061   WCTUSDC    0.07460000             22.933       0.45190163
# 3062   WCTUSDT    0.07440000             22.864       0.45982580
# 3063  PAXGUSDC  107.00000000              3.291    3326.02454787
# 3064   ONDOTRY   -0.82000000             -2.547      31.50191234
# 3065   BABYEUR   -0.00735000             -8.792       0.07865449
#
#      prevClosePrice      lastPrice       lastQty       bidPrice        bidQty  \
# 0        0.01910000     0.01861000    3.60160000     0.01861000   49.08110000
# 1        0.00089500     0.00088500   15.60000000     0.00088500  462.03400000
# 2        0.00693200     0.00692800    0.30900000     0.00693000   10.46400000
# 3        0.00006440     0.00006430   10.30000000     0.00006420  293.31000000
# 4        0.00120100     0.00125400   33.40000000     0.00125500  116.20000000
# ...             ...            ...           ...            ...           ...
# 3061     0.32560000     0.39990000  130.80000000     0.39950000  142.80000000
# 3062     0.32540000     0.39980000   88.50000000     0.39970000  327.90000000
# 3063  3246.00000000  3358.00000000    0.01480000  3356.00000000    1.00080000
# 3064    32.17000000    31.37000000   62.82000000    31.35000000  946.90000000
# 3065     0.08239000     0.07625000  145.00000000     0.07626000  120.00000000
#
#            askPrice  ...      openPrice      highPrice       lowPrice  \
# 0        0.01862000  ...     0.01910000     0.01919000     0.01844000
# 1        0.00088600  ...     0.00089600     0.00091400     0.00087500
# 2        0.00693100  ...     0.00693200     0.00697900     0.00685500
# 3        0.00006430  ...     0.00006440     0.00006730     0.00006240
# 4        0.00125800  ...     0.00121100     0.00125400     0.00121100
# ...             ...  ...            ...            ...            ...
# 3061     0.39980000  ...     0.32530000     0.65390000     0.27630000
# 3062     0.39980000  ...     0.32540000     0.65370000     0.27620000
# 3063  3368.00000000  ...  3251.00000000  3361.00000000  3251.00000000
# 3064    31.37000000  ...    32.19000000    32.37000000    30.65000000
# 3065     0.07713000  ...     0.08360000     0.08360000     0.07625000
#
#                   volume         quoteVolume       openTime      closeTime  \
# 0         25925.56230000        488.24013820  1744743977784  1744830377784
# 1         29245.44800000         26.09121029  1744743977998  1744830377998
# 2          7885.64000000         54.57098875  1744743977994  1744830377994
# 3        148961.17000000          9.61913949  1744743972587  1744830372587
# 4          4267.10000000          5.32245990  1744743972067  1744830372067
# ...                  ...                 ...            ...            ...
# 3061   33299645.80000000   15048164.25321000  1744743977882  1744830377882
# 3062  434397527.40000000  199747191.21033000  1744743978090  1744830378090
# 3063         40.07680000     133296.42060000  1744743956839  1744830356839
# 3064    1288236.33000000   40581907.94330000  1744743975036  1744830375036
# 3065      10571.00000000        831.45664000  1744743972989  1744830372989
#
#         firstId     lastId    count
# 0     492973478  493044457    70980
# 1     104891253  104899431     8179
# 2     271614854  271634557    19704
# 3      47450179   47453507     3329
# 4       5521166    5521225       60
# ...         ...        ...      ...
# 3061      96317     244635   148319
# 3062     426270    1606479  1180210
# 3063         64        399      336
# 3064      32123      47560    15438
# 3065         54         71       18
#
# [3066 rows x 21 columns]

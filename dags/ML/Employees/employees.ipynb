# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
HOME = '/opt/airflow/dags/ML/Employees'

df = pd.read_csv('Employee.csv')
df.head(10)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
# 5  Bachelors         2016  Bangalore            3   22    Male          No
# 6  Bachelors         2015  New Delhi            3   38    Male          No
# 7  Bachelors         2016  Bangalore            3   34  Female          No
# 8  Bachelors         2016       Pune            3   23    Male          No
# 9    Masters         2017  New Delhi            2   37    Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# ...

# %%
# df.info()

# %%
#measuring corr
features = ['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender', 'EverBenched', 'ExperienceInCurrentDomain']
encoded_features = ['Education', 'Gender','EverBenched', 'City']
target = 'LeaveOrNot'

dummies_df = pd.get_dummies(df, columns=encoded_features)
dummies_df.head(2)
# Out:
#    JoiningYear  PaymentTier  Age  ExperienceInCurrentDomain  LeaveOrNot  \
# 0         2017            3   34                          0           0
# 1         2013            1   28                          3           1
#
#    Education_Bachelors  Education_Masters  Education_PHD  Gender_Female  \
# 0                 True              False          False          False
# 1                 True              False          False           True
#
#    Gender_Male  EverBenched_No  EverBenched_Yes  City_Bangalore  \
# 0         True            True            False            True
# 1        False            True            False           False
#
#    City_New Delhi  City_Pune
# 0           False      False
# 1           False       True

# %%
#model
le = LabelEncoder()
df['Education'] = le.fit_transform(df[target])
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0             0         2017  Bangalore            3   34    Male          No
# 1             1         2013       Pune            1   28  Female          No
# 2             0         2014  New Delhi            3   38  Female          No
# 3             1         2016  Bangalore            3   27    Male          No
# 4             1         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648          0         2013  Bangalore            3   26  Female          No
# 4649          1         2013       Pune            2   37    Male          No
# 4650          1         2018  New Delhi            3   27    Male          No
# 4651          0         2012  Bangalore            3   30    Male         Yes
# 4652          0         2015  Bangalore            3   33    Male         Yes
#
# ...
